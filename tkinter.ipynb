# %%
from tkinter import *
window=Tk()
# add widgets here

window.title('Hello Python')
window.geometry("300x200")
window.mainloop()

# %%
from tkinter import *
window=Tk()
btn=Button(window, text="This is Button widget", fg='blue')
btn.place(x=0, y=100)
window.title('Hello Python')
window.geometry("500x200+10+10")
window.mainloop()

# %%
from tkinter import *
import datetime
window=Tk()
lbl=Label(window, text="This is Label widget", fg='red', font=("Helvetica", 16))
lbl.place(x=60, y=50)
window.title('Hello Python')
window.geometry("300x200+10+10")
window.mainloop()

# %%
from tkinter import *
window=Tk()
btn=Button(window, text="This is Button widget", fg='blue')
btn.place(x=80, y=100)
lbl=Label(window, text="This is Label widget", fg='red', font=("Helvetica", 16))
lbl.place(x=60, y=50)
txtfld=Entry(window, text="This is Entry Widget",bd = 1)
txtfld.place(x=80, y=150)
window.title('Hello Python')
window.geometry("300x200+10+10")
window.mainloop()

# %%
from tkinter import *
from tkinter.ttk import Combobox
window=Tk()
var = StringVar()
var.set("one")
data=("one", "two", "three", "four")
cb=Combobox(window, values=data)
cb.place(x=60, y=150)

lb=Listbox(window, height=5, selectmode='multiple')
for num in data:
    lb.insert(END,num)
lb.place(x=250, y=150)

v0=IntVar()
v0.set(1)
r1=Radiobutton(window, text="male", variable=v0,value=1)
r2=Radiobutton(window, text="female", variable=v0,value=2)
r1.place(x=100,y=50)
r2.place(x=180, y=50)
                
v1 = IntVar()
v2 = IntVar()
C1 = Checkbutton(window, text = "Cricket", variable = v1)
C2 = Checkbutton(window, text = "Tennis", variable = v2)
C1.place(x=100, y=100)
C2.place(x=180, y=100)
def show():
    print(v1.get(),v2.get(),v0.get())
    l=Label(window, text="male Selected", fg='red', font=("Helvetica", 16))
    l.place(x=400, y=200)

    
b = Button(window, text="Disp", fg='blue',command = show)
b.place(x=300, y=100)


window.title('Hello Python')
window.geometry("400x300+10+10")
window.mainloop()
# Out:
# 0 0 1

# %%
from tkinter import *
class MyWindow:
    def __init__(self, win):
        self.lbl1=Label(win, text='First Name')
        self.lbl2=Label(win, text='Last Name')
        self.lbl3=Label(win, text='Result')
        self.t1=Entry(bd=3)
        self.t2=Entry()
        self.t3=Entry()
        self.btn1 = Button(win, text='Welcome')
        self.btn2=Button(win, text='Subtract')
        self.lbl1.place(x=100, y=50)
        self.t1.place(x=200, y=50)
        self.lbl2.place(x=100, y=100)
        self.t2.place(x=200, y=100)
        self.b1=Button(win, text='Welcome', command=self.add)
        self.b2=Button(win, text='Subtract',command=self.sub)
        #self.b2.bind('<Button-1>', self.sub)
        self.b1.place(x=100, y=150)
        self.b2.place(x=200, y=150)
        self.lbl3.place(x=100, y=200)
        self.t3.place(x=200, y=200)
    def add(self):
        num1=(self.t1.get())
        num2=(self.t2.get())
        result=num1+num2
        self.t3.insert(END, str(result +"  "+"welcome"+" "+str(datetime.datetime.now())))
    def sub(self):
        num1=int(self.t1.get())
        num2=int(self.t2.get())
        result=num1-num2
        self.t3.insert(END, str(result))

window=Tk()
mywin=MyWindow(window)
window.title('Hello Python')
window.geometry("400x300+10+10")
window.mainloop()

# %%
#import modules
 
from tkinter import *
import os
import sqlite3

from sqlite3 import Error
 
# Designing window for registration
 
def register():
    global register_screen
    register_screen = Toplevel(main_screen)
    register_screen.title("Register")
    register_screen.geometry("300x250")
 
    global username
    global password
    global username_entry
    global password_entry
    username = StringVar()
   
    password = StringVar()
 
    Label(register_screen, text="Please enter details below", bg="blue").pack()
    Label(register_screen, text="").pack()
    username_lable = Label(register_screen, text="Username * ")
    username_lable.pack()
    username_entry = Entry(register_screen, textvariable=username)
    #print(username_entry.get())
    username_entry.pack()
    password_lable = Label(register_screen, text="Password * ")
    password_lable.pack()
    password_entry = Entry(register_screen, textvariable=password, show='*')
    password_entry.pack()
    Label(register_screen, text="").pack()
    Button(register_screen, text="Register", width=10, height=1, bg="blue", command = register_user).pack()
 
 
# Designing window for login 
 
def login():
    global login_screen
    login_screen = Toplevel(main_screen)
    login_screen.title("Login")
    login_screen.geometry("300x250")
    Label(login_screen, text="Please enter details below to login").pack()
    Label(login_screen, text="").pack()
 
    global username_verify
    global password_verify
 
    username_verify = StringVar()
    password_verify = StringVar()
 
    global username_login_entry
    global password_login_entry
 
    Label(login_screen, text="Username * ").pack()
    username_login_entry = Entry(login_screen, textvariable=username_verify)
    username_login_entry.pack()
    Label(login_screen, text="").pack()
    Label(login_screen, text="Password * ").pack()
    password_login_entry = Entry(login_screen, textvariable=password_verify, show= '*')
    password_login_entry.pack()
    Label(login_screen, text="").pack()
    Button(login_screen, text="Login", width=10, height=1, command = login_verify).pack()
 
# Implementing event on register button
 
def register_user():
    global con 
 
    username_info = username.get()
    #print(username_info)
    password_info = password.get()
    
    cursorObj = con.cursor()
    cursorObj.execute('INSERT INTO logincredentials(username, password) VALUES(?, ?)', (username_info,password_info))
    con.commit()
 
    '''file = open(username_info, "w")
    file.write(username_info + "\n")
    file.write(password_info)
    file.close()'''
 
    username_entry.delete(0, END)
    password_entry.delete(0, END)
 
    Label(register_screen, text="Registration Success", fg="green", font=("calibri", 11)).pack()
 
# Implementing event on login button 
 
def login_verify():
    global con 
    username1 = username_verify.get()
    password1 = password_verify.get()
    username_login_entry.delete(0, END)
    password_login_entry.delete(0, END)
    cursorObj = con.cursor()
    
    cursorObj.execute('SELECT * from logincredentials WHERE username="%s" AND password="%s"' % (username1, password1))
    
    row = cursorObj.fetchone()
    print(row)
   
    if username1 in row[1]:
        print("username",row[1])
        user_found()
        
        if password1 in row[2]:
            print("pswd",row[2])
            login_sucess()
 
        else:
            password_not_recognised()
 
    else:
        user_not_found()
 
# Designing popup for login success
 
def login_sucess():
    global login_success_screen
    login_success_screen = Toplevel(login_screen)
    login_success_screen.title("Success")
    login_success_screen.geometry("150x100")
    Label(login_success_screen, text="Login Success").pack()
    Button(login_success_screen, text="OK", command=delete_login_success).pack()
 
# Designing popup for login invalid password
 
def password_not_recognised():
    global password_not_recog_screen
    password_not_recog_screen = Toplevel(login_screen)
    password_not_recog_screen.title("Success")
    password_not_recog_screen.geometry("150x100")
    Label(password_not_recog_screen, text="Invalid Password ").pack()
    Button(password_not_recog_screen, text="OK", command=delete_password_not_recognised).pack()
 
# Designing popup for user not found
 
def user_not_found():
    global user_not_found_screen
    user_not_found_screen = Toplevel(login_screen)
    user_not_found_screen.title("Success")
    user_not_found_screen.geometry("150x100")
    Label(user_not_found_screen, text="User Not Found").pack()
    Button(user_not_found_screen, text="OK", command=delete_user_not_found_screen).pack()
    
def user_found():
    global user_found_screen
    user_found_screen = Toplevel(login_screen)
    user_found_screen.title("Success")
    user_found_screen.geometry("150x100")
    Label(user_found_screen, text="User Found").pack()
    Button(user_found_screen, text="OK", command=delete_user_found_screen).pack()
 
# Deleting popups
 
def delete_login_success():
    login_success_screen.destroy()
 
 
def delete_password_not_recognised():
    password_not_recog_screen.destroy()
 
 
def delete_user_not_found_screen():
    user_not_found_screen.destroy()
    
def delete_user_found_screen():
    user_found_screen.destroy()
 
# Designing Main(first) window

 
  
    
con = "" # db handler   
    
def main_account_screen():
    global con
    con = sqlite3.connect('loginusername.db')
    cursorObj = con.cursor()
    cursorObj.execute('create table if not exists logincredentials \
              (ID INTEGER PRIMARY KEY AUTOINCREMENT, username text NOT NULL, password text NOT NULL);')
    con.commit()
    global main_screen
    main_screen = Tk()
    main_screen.geometry("300x250")
    main_screen.title("Account Login")
    Label(text="Select Your Choice", bg="white", width="300", height="2", font=("Calibri", 13)).pack()
    Label(text="").pack()
    Button(text="Login", height="2", width="30", command = login).pack()
    Label(text="").pack()
    Button(text="Register", height="2", width="30", command=register).pack()
 
    main_screen.mainloop()
 
 
main_account_screen()
# Out:
# (1, 'vin', 'vin')
# username vin
# pswd vin

# %%
import sqlite3
db = sqlite3.connect('loginusername.db')
c = db.cursor()
c.execute('create table if not exists logincredentials \
              (ID INTEGER PRIMARY KEY AUTOINCREMENT, username text NOT NULL, password text NOT NULL);')
#c.execute('INSERT INTO usercredentials(username, password) VALUES(?, ?)', ("sdf","sdf"))
#db.commit()

c.execute('SELECT * FROM logincredentials')
#c.execute('drop table logincredentials')
row = c.fetchall()
print(row)
#for i in row:
#    print(i)
db.close()
# Out:
# [(1, 'vin', 'vin'), (2, 'wdw', 'edwdwd'), (3, 'vin', 'vin'), (4, 'vb', 'vb'), (5, '1234', '1234'), (6, 'vin', 'vin'), (7, '', ''), (8, 'vin', 'vin')]

# %%
import sqlite3
from tkinter import *  
from PIL import ImageTk,Image 
import io 
root = Tk()  
canvas = Canvas(root, width = 300, height = 300)  
canvas.pack()  
def pic(photo):
    with open(photo, "rb") as imageFile:
        bimage = imageFile.read()
        #print(bimage)
        return bimage

db = sqlite3.connect('images.db')
c = db.cursor()
c.execute('create table if not exists imagescredentials \
              (ID INTEGER PRIMARY KEY AUTOINCREMENT, username text NOT NULL, password text NOT NULL,image BLOB NOT NULL);')
c.execute('INSERT INTO imagescredentials (username, password,image) VALUES(?, ?,?)', ("qdsad","sdf",pic("carr.jpg")))
row = c.execute('select * from  imagescredentials')
db.commit()
file_like2 = io.BytesIO(tuple(row)[0][3])# open image file 
load = Image.open(file_like2)
render = ImageTk.PhotoImage(load)
img = Label(image=render)
img.image = render
img.place(x=0, y=0)  
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-ca2c92be4d5d> in <module>()
#      15 c = db.cursor()
#      16 c.execute('create table if not exists imagescredentials               (ID INTEGER PRIMARY KEY AUTOINCREMENT, username text NOT NULL, password text NOT NULL,image BLOB NOT NULL);')
# ---> 17 c.execute('INSERT INTO imagescredentials (username, password,image) VALUES(?, ?,?)', ("qdsad","sdf",pic("carr.jpg")))
#      18 row = c.execute('select * from  imagescredentials')
#      19 db.commit()
#
# <ipython-input-10-ca2c92be4d5d> in pic(photo)
#       7 canvas.pack()
#       8 def pic(photo):
# ----> 9     with open(photo, "rb") as imageFile:
#      10         bimage = imageFile.read()
#      11         #print(bimage)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'carr.jpg'

# %%
import base64
import sqlite3
def convertToBinaryData(filename):
    #Convert digital data to binary format
    with open(filename, 'rb') as file:
        binaryData = file.read()
    return binaryData

def pic(photo):
    with open(photo, "rb") as imageFile:
        bimage = imageFile.read()
        return bimage
def insertBLOB(emp_id, name, photo, biodataFile):
    print("Inserting BLOB into python_employee table")
    try:
        connection =sqlite3.connect('loginusername.db')
        cursor = connection.cursor()
        cursor.execute('create table if not exists imagescredentials1 \
              (ID INTEGER PRIMARY KEY AUTOINCREMENT, name text NOT NULL, photo BLOB NOT NULL,biodata BLOB NOT NULL);')
        sql_insert_blob_query = """ INSERT INTO 'imagescredentials1'
                          ('ID', 'name', 'photo', 'biodata') VALUES (?,?,?,?)"""
        empPicture = pic(photo)
        file = convertToBinaryData(biodataFile)
        # Convert data into tuple format
        insert_blob_tuple = (emp_id, name, empPicture, file)
        result  = cursor.execute(sql_insert_blob_query, insert_blob_tuple)
        connection.commit()
        print ("Image and file inserted successfully as a BLOB into python_employee table", result)
    except mysql.connector.Error as error :
        connection.rollback()
        print("Failed inserting BLOB data into MySQL table {}".format(error))
    finally:
        #closing database connection.
        if(connection.is_connected()):
            cursor.close()
            connection.close()
            print("MySQL connection is closed")
insertBLOB(11, "vin1", "images.jpg", "kmv.txt")
#insertBLOB(56, "modi1", "images.jpg","kmv.txt")
# Out:
# Inserting BLOB into python_employee table
# Image and file inserted successfully as a BLOB into python_employee table <sqlite3.Cursor object at 0x000001EBE48F4340>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-d1322850467a> in <module>()
#      36             connection.close()
#      37             print("MySQL connection is closed")
# ---> 38 insertBLOB(11, "vin1", "images.jpg", "kmv.txt")
#      39 #insertBLOB(56, "modi1", "images.jpg","kmv.txt")
#
# <ipython-input-32-d1322850467a> in insertBLOB(emp_id, name, photo, biodataFile)
#      32     finally:
#      33         #closing database connection.
# ---> 34         if(connection.is_connected()):
#      35             cursor.close()
#      36             connection.close()
#
# AttributeError: 'sqlite3.Connection' object has no attribute 'is_connected'

# %%
# convert binary into file like object to show image 
import sqlite3
from PIL import Image
import base64
import io 
import PIL.Image
db = sqlite3.connect('loginusername.db')
c = db.cursor()


c.execute('SELECT * FROM imagescredentials1')
row = c.fetchall()
k = row[-1][2]

#print(k)
file_like2 = io.BytesIO(k)

#img1=Image.open(file_like2)
#img1.show()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-217f3373d968> in <module>()
#       9
#      10
# ---> 11 c.execute('SELECT * FROM imagescredentials1')
#      12 row = c.fetchall()
#      13 k = row[-1][2]
#
# OperationalError: no such table: imagescredentials1

# %%
# show image from binary file 
from tkinter import *

# pip install pillow
from PIL import Image, ImageTk

class Window(Frame):
    def __init__(self, master=None):
        Frame.__init__(self, master)
        self.master = master
        self.pack(fill=BOTH, expand=1)
        
        load = Image.open(file_like2)# from previous cell 
        render = ImageTk.PhotoImage(load)
        img = Label(self, image=render)
        img.image = render
        img.place(x=0, y=0)

        
root = Tk()
app = Window(root)
root.wm_title("Tkinter window")
root.geometry("200x120")
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d597a2338724> in <module>()
#      19
#      20 root = Tk()
# ---> 21 app = Window(root)
#      22 root.wm_title("Tkinter window")
#      23 root.geometry("200x120")
#
# <ipython-input-12-d597a2338724> in __init__(self, master)
#      11         self.pack(fill=BOTH, expand=1)
#      12
# ---> 13         load = Image.open(file_like2)# from previous cell
#      14         render = ImageTk.PhotoImage(load)
#      15         img = Label(self, image=render)
#
# NameError: name 'file_like2' is not defined

# %%
r = [(4, 'zxc', 'zxc'), (11, 'zxc', 'zxc')]
r[0]
# Out:
# (4, 'zxc', 'zxc')

# %%
#import modules
 
from tkinter import *
import os
import sqlite3

from sqlite3 import Error
 
# Designing window for registration
 
def register():
    global register_screen
    register_screen = Toplevel(main_screen)
    register_screen.title("Register")
    register_screen.geometry("300x250")
 
    global username
    global password
    global username_entry
    global password_entry
    username = StringVar()
   
    password = StringVar()
 
    Label(register_screen, text="Please enter details below", bg="blue").pack()
    Label(register_screen, text="").pack()
    username_lable = Label(register_screen, text="Username * ")
    username_lable.pack()
    username_entry = Entry(register_screen, textvariable=username)
    #print(username_entry.get())
    username_entry.pack()
    password_lable = Label(register_screen, text="Password * ")
    password_lable.pack()
    password_entry = Entry(register_screen, textvariable=password, show='*')
    password_entry.pack()
    Label(register_screen, text="").pack()
    Button(register_screen, text="Register", width=10, height=1, bg="blue", command = register_user).pack()
 
 
# Designing window for login 
 
def login():
    global login_screen
    login_screen = Toplevel(main_screen)
    login_screen.title("Login")
    login_screen.geometry("300x250")
    Label(login_screen, text="Please enter details below to login").pack()
    Label(login_screen, text="").pack()
 
    global username_verify
    global password_verify
 
    username_verify = StringVar()
    password_verify = StringVar()
 
    global username_login_entry
    global password_login_entry
 
    Label(login_screen, text="Username * ").pack()
    username_login_entry = Entry(login_screen, textvariable=username_verify)
    username_login_entry.pack()
    Label(login_screen, text="").pack()
    Label(login_screen, text="Password * ").pack()
    password_login_entry = Entry(login_screen, textvariable=password_verify, show= '*')
    password_login_entry.pack()
    Label(login_screen, text="").pack()
    Button(login_screen, text="Login", width=10, height=1, command = login_verify).pack()
 
# Implementing event on register button
 
def register_user():
    global con 
 
    username_info = username.get()
    #print(username_info)
    password_info = password.get()
    
    cursorObj = con.cursor()
    cursorObj.execute('INSERT INTO logincredentials(username, password) VALUES(?, ?)', (username_info,password_info))
    con.commit()
 
    '''file = open(username_info, "w")
    file.write(username_info + "\n")
    file.write(password_info)
    file.close()'''
 
    username_entry.delete(0, END)
    password_entry.delete(0, END)
 
    Label(register_screen, text="Registration Success", fg="green", font=("calibri", 11)).pack()
 
# Implementing event on login button 
 
def login_verify():
    global con 
    username1 = username_verify.get()
    password1 = password_verify.get()
    username_login_entry.delete(0, END)
    password_login_entry.delete(0, END)
    cursorObj = con.cursor()
    
    cursorObj.execute('SELECT * from logincredentials WHERE username="%s" AND password="%s"' % (username1, password1))
    
    row = cursorObj.fetchone()
    print(row)
   
    if username1 in row[1]:
        print("username",row[1])
        user_found()
        
        if password1 in row[2]:
            print("pswd",row[2])
            login_sucess()
 
        else:
            password_not_recognised()
 
    else:
        user_not_found()
 
# Designing popup for login success
 
def login_sucess():
    global login_success_screen
    login_success_screen = Toplevel(login_screen)
    login_success_screen.title("Success")
    login_success_screen.geometry("150x100")
    Label(login_success_screen, text="Login Success").pack()
    Button(login_success_screen, text="OK", command=delete_login_success).pack()
 
# Designing popup for login invalid password
 
def password_not_recognised():
    global password_not_recog_screen
    password_not_recog_screen = Toplevel(login_screen)
    password_not_recog_screen.title("Success")
    password_not_recog_screen.geometry("150x100")
    Label(password_not_recog_screen, text="Invalid Password ").pack()
    Button(password_not_recog_screen, text="OK", command=delete_password_not_recognised).pack()
 
# Designing popup for user not found
 
def user_not_found():
    global user_not_found_screen
    user_not_found_screen = Toplevel(login_screen)
    user_not_found_screen.title("Success")
    user_not_found_screen.geometry("150x100")
    Label(user_not_found_screen, text="User Not Found").pack()
    Button(user_not_found_screen, text="OK", command=delete_user_not_found_screen).pack()
    
def user_found():
    global user_found_screen
    user_found_screen = Toplevel(login_screen)
    user_found_screen.title("Success")
    user_found_screen.geometry("150x100")
    Label(user_found_screen, text="User Found").pack()
    Button(user_found_screen, text="OK", command=delete_user_found_screen).pack()
 
# Deleting popups
 
def delete_login_success():
    login_success_screen.destroy()
 
 
def delete_password_not_recognised():
    password_not_recog_screen.destroy()
 
 
def delete_user_not_found_screen():
    user_not_found_screen.destroy()
    
def delete_user_found_screen():
    user_found_screen.destroy()
 
# Designing Main(first) window

 
  
    
con = "" # db handler   
    
def main_account_screen():
    global con
    con = sqlite3.connect('loginusername.db')
    cursorObj = con.cursor()
    cursorObj.execute('create table if not exists logincredentials \
              (ID INTEGER PRIMARY KEY AUTOINCREMENT, username text NOT NULL, password text NOT NULL);')
    con.commit()
    global main_screen
    main_screen = Tk()
    main_screen.geometry("300x250")
    main_screen.title("Account Login")
    Label(text="Select Your Choice", bg="white", width="300", height="2", font=("Calibri", 13)).pack()
    Label(text="").pack()
    Button(text="Login", height="2", width="30", command = login).pack()
    Label(text="").pack()
    Button(text="Register", height="2", width="30", command=register).pack()
 
    main_screen.mainloop()
 
 
main_account_screen()
# Out:
# (5, '1234', '1234')
# username 1234
# pswd 1234

# %%
from tkinter import *
import tkinter as ttk
from tkinter.ttk import *

root = Tk()
root.title("Asset Entry")

# Add a grid
mainframe = Frame(root)
mainframe.grid(column=0,row=0, sticky=(N,W,E,S) )
mainframe.columnconfigure(0, weight = 1)
mainframe.rowconfigure(0, weight = 1)
mainframe.pack(pady = 100, padx = 100)

# Create a Tkinter variable
tkvar = StringVar(root)

# Dictionary with options
choices = { 'AssDrillbit','Crankshaft','RFID-CARD','READER','LAPTOP',"MOUSE","KEYBOARD"}
tkvar.set('Crankshaft') # set the default option

popupMenu = OptionMenu(mainframe, tkvar, *choices)
Label(mainframe, text="Choose Type of Asset").grid(row = 1, column = 1)
popupMenu.grid(row = 2, column =1)


L1 = Label(mainframe, text="User Name")
#L1.pack( side = LEFT)
tkvarentry = StringVar(root)
E1 = Entry(mainframe, value =tkvarentry)
#E1.pack(side = RIGHT)


# on change dropdown value
def change_dropdown(*args):
    print( tkvar.get() )

# link function to change dropdown
tkvar.trace('w', change_dropdown)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-3-b740cefb5b27> in <module>()
#      28 #L1.pack( side = LEFT)
#      29 tkvarentry = StringVar(root)
# ---> 30 E1 = Entry(mainframe, value =tkvarentry)
#      31 #E1.pack(side = RIGHT)
#      32
#
# C:\ProgramData\Anaconda3\lib\tkinter\ttk.py in __init__(self, master, widget, **kw)
#     669             none, key, focus, focusin, focusout, all
#     670         """
# --> 671         Widget.__init__(self, master, widget or "ttk::entry", kw)
#     672
#     673
#
# C:\ProgramData\Anaconda3\lib\tkinter\ttk.py in __init__(self, master, widgetname, kw)
#     557             # Load tile now, if needed
#     558             _load_tile(master)
# --> 559         tkinter.Widget.__init__(self, master, widgetname, kw=kw)
#     560
#     561
#
# ...

# %%
#!/usr/bin/python3
import datetime
import tkinter as tk
import pyqrcode
import json
import png
import os


from PIL import Image, ImageTk


fields = ('AssetType', 'AssetID', 'AssetDept', 'AssetOwner', 'ShelfLife')

def jsondata(entries):
    # period rate:
    AssetType = entries['AssetType'].get()
    
    # principal loan:
    AssetDept = entries['AssetDept'].get()
    AssetID =  entries['AssetID'].get()
    ShelfLife = entries['ShelfLife'].get()
    json_data = {'AssetDept':entries['AssetDept'].get(),
                'AssetType':entries['AssetType'].get(),
                'AssetID': entries['AssetID'].get(),
                'ShelfLife':entries['ShelfLife'].get(),
                'EntryDate':str(datetime.datetime.now())}
    #print(json_data)
    global preview_screen
    global root
    preview_screen = tk.Toplevel(root)
    preview_screen.title("Preview Data")
    preview_screen.geometry("300x250")
    tk.Label(preview_screen, text=json_data,wraplength = 300).pack()
    

def qrcode(entries):
    global root
    json_data = {'AssetDept':entries['AssetDept'].get(),
                'AssetType':entries['AssetType'].get(),
                'AssetID': entries['AssetID'].get(),
                'ShelfLife':entries['ShelfLife'].get(),
                'EntryDate':str(datetime.datetime.now())}
     #print(json_data)
    url = pyqrcode.create(json.dumps(json_data))
    url.png(entries['AssetID'].get()+".png", scale=8)
    image = Image.open(entries['AssetID'].get()+".png")
    photo = ImageTk.PhotoImage(image)
    
    global qr_screen
    global root
    qr_screen = tk.Toplevel(root)
    qr_screen.title("QR Code")
    qr_screen.geometry("500x250")
    label = tk.Label(qr_screen).pack()
    label = tk.Label(qr_screen,image=photo)
    label.image = photo # keep a reference!
    label.pack()
    

def makeform(root, fields):
    entries = {}
    for field in fields:
        #print(field)
        row = tk.Frame(root)
        lab = tk.Label(row, width=22, text=field+": ", anchor='w')
        ent = tk.Entry(row)
        ent.insert(0, "0")
        row.pack(side=tk.TOP, 
                 fill=tk.X, 
                 padx=5, 
                 pady=5)
        lab.pack(side=tk.LEFT)
        ent.pack(side=tk.RIGHT, 
                 expand=tk.YES, 
                 fill=tk.X)
        entries[field] = ent
    #print("sdfsdfsdf",entries)
    return entries

if __name__ == '__main__':
    global root
    root = tk.Tk()
    ents = makeform(root, fields)
    b1 = tk.Button(root, text='QR Code',
           command=(lambda e=ents:qrcode(ents)))
    b1.pack(side=tk.LEFT, padx=5, pady=5)
    b2 = tk.Button(root, text='Preview',
           command=(lambda e=ents: jsondata(e)))
    b2.pack(side=tk.LEFT, padx=5, pady=5)
    b3 = tk.Button(root, text='Quit', command=root.quit)
    b3.pack(side=tk.LEFT, padx=5, pady=5)
    root.mainloop()

# %%
#!/usr/bin/python3
import datetime
import tkinter as tk
import pyqrcode
import json
import png
import os
import boto3
from PIL import Image, ImageTk
import os

###########################################AWS S3 bucket########################
ACCESS_KEY =  'AKIAQ66RZB34EOCCQ6NB'
SECRET_KEY = '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'
S3_LOCATION = 'http://{}.s3.amazonaws.com/'.format('iotadaka')
s3 = boto3.client(
"s3",
aws_access_key_id=ACCESS_KEY,
aws_secret_access_key=SECRET_KEY
)
bucket_resource = s3
bucket_name = "iotadaka"
###########################################AWS S3 bucket########################

fields = ('AssetType', 'AssetID', 'AssetDept', 'AssetOwner', 'ShelfLife')

def jsondata(entries):
    # period rate:
    AssetType = entries['AssetType'].get()
    
    # principal loan:
    AssetDept = entries['AssetDept'].get()
    AssetID =  entries['AssetID'].get()
    ShelfLife = entries['ShelfLife'].get()
    json_data = {'AssetDept':entries['AssetDept'].get(),
                'AssetType':entries['AssetType'].get(),
                'AssetID': entries['AssetID'].get(),
                'ShelfLife':entries['ShelfLife'].get(),
                'EntryDate':str(datetime.datetime.now()),
                "AssetOwner":entries['AssetOwner'].get()}
    #print(json_data)
    global preview_screen
    global root
    preview_screen = tk.Toplevel(root)
    preview_screen.title("Preview Data")
    preview_screen.geometry("300x250")
    tk.Label(preview_screen, text=json_data,wraplength = 300).pack()
    

def qrcode(entries):
    from PIL import Image
    from PIL import ImageFont
    from PIL import ImageDraw 
    global root
    global bucket_resource
    global bucket_name 
    json_data = {'AssetDept':entries['AssetDept'].get(),
                'AssetType':entries['AssetType'].get(),
                'AssetID': entries['AssetID'].get(),
                'ShelfLife':entries['ShelfLife'].get(),
                'EntryDate':str(datetime.datetime.now()),
                "AssetOwner":entries['AssetOwner'].get()}
     #print(json_data)
    url = pyqrcode.create(json.dumps(json_data))
    filename = entries['AssetID'].get()+".png"
    url.png(filename, scale=4,quiet_zone=10)
    image = Image.open(filename)#entries['AssetID'].get()+".jpg")
    draw = ImageDraw.Draw(image)
    #font = ImageFont.truetype(<font-file>, <font-size>)
    font = ImageFont.truetype("abel-regular.ttf", 16)
    #draw.text((x, y),"Sample Text",(r,g,b))
    draw.text((0, 0),entries['AssetID'].get()+":"+entries['AssetType'].get()+'\n'+json_data['EntryDate'],(0),font=font)
    image.save(filename)
    
    #############################uplad to S3###########################
    bucket_resource.upload_file(Bucket = bucket_name,
                                Filename=filename,
                                Key=filename
                                )
    ###################################################################
    photo = ImageTk.PhotoImage(image)
    
    global qr_screen
    global root
    qr_screen = tk.Toplevel(root)
    qr_screen.title("QR Code")
    qr_screen.geometry("500x250")
    label = tk.Label(qr_screen).pack()
    label = tk.Label(qr_screen,image=photo)
    label.image = photo # keep a reference!
    label.pack()
    

def makeform(root, fields):
    entries = {}
    for field in fields:
        #print(field)
        row = tk.Frame(root)
        lab = tk.Label(row, width=22, text=field+": ", anchor='w')
        ent = tk.Entry(row)
        ent.insert(0, "0")
        row.pack(side=tk.TOP, 
                 fill=tk.X, 
                 padx=5, 
                 pady=5)
        lab.pack(side=tk.LEFT)
        ent.pack(side=tk.RIGHT, 
                 expand=tk.YES, 
                 fill=tk.X)
        entries[field] = ent
    #print("sdfsdfsdf",entries)
    return entries

if __name__ == '__main__':
    global root
    root = tk.Tk()
    ents = makeform(root, fields)
    b1 = tk.Button(root, text='QR Code',
           command=(lambda e=ents:qrcode(e)))
    b1.pack(side=tk.LEFT, padx=5, pady=5)
    b2 = tk.Button(root, text='Preview',
           command=(lambda e=ents: jsondata(e)))
    b2.pack(side=tk.LEFT, padx=5, pady=5)
    b3 = tk.Button(root, text='Quit', command=root.quit)
    b3.pack(side=tk.LEFT, padx=5, pady=5)
    root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\boto3-1.9.130-py3.6.egg\boto3\s3\transfer.py", line 279, in upload_file
#     future.result()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\s3transfer-0.2.0-py3.6.egg\s3transfer\futures.py", line 106, in result
#     return self._coordinator.result()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\s3transfer-0.2.0-py3.6.egg\s3transfer\futures.py", line 265, in result
#     raise self._exception
#   File "C:\ProgramData\Anaconda3\lib\site-packages\s3transfer-0.2.0-py3.6.egg\s3transfer\tasks.py", line 126, in __call__
#     return self._execute_main(kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\s3transfer-0.2.0-py3.6.egg\s3transfer\tasks.py", line 150, in _execute_main
#     return_value = self._main(**kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\s3transfer-0.2.0-py3.6.egg\s3transfer\upload.py", line 692, in _main
# ...

# %%
import os
ACCESS_KEY =  'AKIAQ66RZB34EOCCQ6NB'
SECRET_KEY = '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'
S3_LOCATION = 'http://{}.s3.amazonaws.com/'.format('iotadaka')
s3 = boto3.client(
"s3",
aws_access_key_id=ACCESS_KEY,
aws_secret_access_key=SECRET_KEY
)
bucket_resource = s3

#img = request.files['img']
filename = 'we.jpg'
#if img:
#filename = secure_filename(filename)
bucket_resource.upload_file(
Bucket = 'iotadaka',
Filename=filename,
Key=filename
)
# Out:
# ---------------------------------------------------------------------------
# NoSuchBucket                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\boto3-1.9.130-py3.6.egg\boto3\s3\transfer.py in upload_file(self, filename, bucket, key, callback, extra_args)
#     278         try:
# --> 279             future.result()
#     280         # If a client error was raised, add the backwards compatibility layer
#
# C:\ProgramData\Anaconda3\lib\site-packages\s3transfer-0.2.0-py3.6.egg\s3transfer\futures.py in result(self)
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\s3transfer-0.2.0-py3.6.egg\s3transfer\futures.py in result(self)
#     264         if self._exception:
# --> 265             raise self._exception
#     266         return self._result
#
# ...

# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw 
img = Image.open("we.jpg")
draw = ImageDraw.Draw(img)
font = ImageFont.truetype("abel-regular.ttf", 16)
draw.text((0, 0),"Draw This Text",(0,0,0),font=font) # this will draw text with Blackcolor and 16 size

img.save('sampsdsdle-out.jpg')
