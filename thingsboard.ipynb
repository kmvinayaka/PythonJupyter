# %%
import os
import time
import sys
#import Adafruit_DHT as dht
import paho.mqtt.client as mqtt
import json
import random

THINGSBOARD_HOST = 'demo.thingsboard.io'
ACCESS_TOKEN = 'eXsxr15SDZh512gMUlAL'

# Data capture and upload interval in seconds. Less interval will eventually hang the DHT22.
INTERVAL=2

sensor_data = {'temperature': 0, 'humidity': 0}

next_reading = time.time() 

client = mqtt.Client()

# Set access token
client.username_pw_set(ACCESS_TOKEN)

# Connect to ThingsBoard using default MQTT port and 60 seconds keepalive interval
client.connect(THINGSBOARD_HOST, 1883, 60)

client.loop_start()

try:
    while True:
        humidity,temperature = random.randint(40,85),random.randint(0,100)#.dht.read_retry(dht.DHT22, 4)
        humidity = round(humidity, 2)
        temperature = round(temperature, 2)
        print("Temperature: {0}\u00b0C, Humidity: {1}%".format(temperature, humidity))
        sensor_data['temperature'] = temperature
        sensor_data['humidity'] = humidity
        print(sensor_data)

        # Sending humidity and temperature data to ThingsBoard
        client.publish('v1/devices/me/telemetry', json.dumps(sensor_data), 1)

        next_reading += INTERVAL
        sleep_time = next_reading-time.time()
        if sleep_time > 0:
            time.sleep(sleep_time)
except KeyboardInterrupt:
    pass

client.loop_stop()
client.disconnect()
# Out:
# Temperature: 61°C, Humidity: 46%
# {'temperature': 61, 'humidity': 46}
# Temperature: 90°C, Humidity: 67%
# {'temperature': 90, 'humidity': 67}
# Temperature: 98°C, Humidity: 80%
# {'temperature': 98, 'humidity': 80}
# Temperature: 93°C, Humidity: 44%
# {'temperature': 93, 'humidity': 44}
# Temperature: 46°C, Humidity: 48%
# {'temperature': 46, 'humidity': 48}
# Temperature: 91°C, Humidity: 65%
# {'temperature': 91, 'humidity': 65}
# Temperature: 6°C, Humidity: 64%
# {'temperature': 6, 'humidity': 64}
# Temperature: 93°C, Humidity: 53%
# {'temperature': 93, 'humidity': 53}
# Temperature: 48°C, Humidity: 61%
# {'temperature': 48, 'humidity': 61}
# Temperature: 38°C, Humidity: 59%
# {'temperature': 38, 'humidity': 59}
# Temperature: 62°C, Humidity: 63%
# {'temperature': 62, 'humidity': 63}
# Temperature: 53°C, Humidity: 55%
# {'temperature': 53, 'humidity': 55}
# Temperature: 18°C, Humidity: 67%
# {'temperature': 18, 'humidity': 67}
# Temperature: 52°C, Humidity: 40%
# {'temperature': 52, 'humidity': 40}
# Temperature: 33°C, Humidity: 78%
# {'temperature': 33, 'humidity': 78}
# Temperature: 82°C, Humidity: 73%
# {'temperature': 82, 'humidity': 73}
# Temperature: 64°C, Humidity: 63%
# {'temperature': 64, 'humidity': 63}
# Temperature: 88°C, Humidity: 45%
# {'temperature': 88, 'humidity': 45}
# Temperature: 77°C, Humidity: 60%
# {'temperature': 77, 'humidity': 60}
# Temperature: 88°C, Humidity: 50%
# {'temperature': 88, 'humidity': 50}
# Temperature: 11°C, Humidity: 68%
# {'temperature': 11, 'humidity': 68}
# Temperature: 86°C, Humidity: 40%
# {'temperature': 86, 'humidity': 40}
# Temperature: 64°C, Humidity: 46%
# {'temperature': 64, 'humidity': 46}
# Temperature: 40°C, Humidity: 71%
# {'temperature': 40, 'humidity': 71}
# Temperature: 39°C, Humidity: 46%
# {'temperature': 39, 'humidity': 46}
# Temperature: 86°C, Humidity: 65%
# {'temperature': 86, 'humidity': 65}
# Temperature: 73°C, Humidity: 59%
# {'temperature': 73, 'humidity': 59}
# Temperature: 89°C, Humidity: 84%
# {'temperature': 89, 'humidity': 84}
# 0
